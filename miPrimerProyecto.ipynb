# %% [markdown]
# <a href="https://colab.research.google.com/github/jimrobert796/PrograIII-Semi-2026/blob/main/miPrimerProyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sume dos numeros")
num1 = input("Ingrese numero: ")
num2 = input("Ingrese numero: ")


res = float(num1) + float(num2)
print(type(res))

print(f"Su resultado {res}")

res = "suma completada"
# Out:
# Sume dos numeros
# Ingrese numero: 2
# Ingrese numero: 2
# <class 'float'>
# Su resultado 4.0  3

# %%
print("Reste dos numeros")
num1 = input("Ingrese numero: ")
num2 = input("Ingrese numero: ")


res = float(num1) - float(num2)
print(type(res))

print(f"Su resultado {res}")

res = "suma completada"
# Out:
# Reste dos numeros
# Ingrese numero: 2
# Ingrese numero: 1
# <class 'float'>
# Su resultado 1.0  1

# %%
print("Multiplique dos numeros")
num1 = input("Ingrese numero: ")
num2 = input("Ingrese numero: ")


res = float(num1) * float(num2)
print(type(res))

print(f"Su resultado {res}")

res = "suma completada"
# Out:
# Multiplique dos numeros
# Ingrese numero: 4
# Ingrese numero: 2
# <class 'float'>
# Su resultado 8.0

# %%
print("divida dos numeros")
num1 = input("Ingrese numero: ")
num2 = input("Ingrese numero: ")


res = float(num1) / float(num2)
print(type(res))

print(f"Su resultado {res}")

res = "suma completada"

# %%
saludo = "Hola chicos de progra"
print("Primer elemento de la cadena:", saludo[0])
print("Rango de la cadena:", saludo[0:19])
print("Ultimo elemento:", saludo[-1])
print("Ultimo elemento:",saludo[len(saludo)-1])
print("Valores en medio, sin especificar ultimo valor:", saludo[:5])
print("Sin valor de inicio:", saludo[:4])
print("Contar el final:", saludo[5:-1])
# Out:
# Primer elemento de la cadena: H
# Rango de la cadena: Hola chicos de prog
# Ultimo elemento: a
# Ultimo elemento: a
# Valores en medio: Hola

# %% [markdown]
# **Funciones en python**

# %%
def resta(num1, num2):
  return float(num1) - float(num2)

# %%
def suma(num1, num2):
  return float(num1) + float(num2)

# %%
num1 = input("Ingrese el primer numero: ")
num2 = input("Ingrese el segundo numero: ")
print("La suma es: ", suma(num1, num2))
print("La resta es: ", resta(num1, num2))
# Out:
# Ingrese el primer numero: 12
# Ingrese el segundo numero: 2
# La suma es:  14.0
# La resta es:  10.0

# %% [markdown]
# Hacer en python el siguiente ejercicio haciendo uso de funciones, que convierta de grados celcuis a farenheit

# %%
def convertir(celcuis):
  return float(celcuis) * 9/5 + 32

# %%
celcuis = input("Ingrese los grados celcuis: ")
print("Los grados farenheit son: ", convertir(celcuis))
# Out:
# Ingrese los grados celcuis: 33
# Los grados farenheit son:  91.4

# %% [markdown]
# Hacer en python el siguiente ejercicio haciendo uso de funciones, que convierta de grados farenheit a celcuis

# %%
def convertirFaren(farenheit):
  return (float(farenheit) -32) * 9/5

# %%
faren = input("Ingrese los grados farenheit: ")
print("Los grados celcuis son: ", convertirFaren(faren))
# Out:
# Ingrese los grados farenheit: 32
# Los grados celcuis son:  0.0

# %% [markdown]
# Hacer en python el siguiente ejercicio haciendo uso de funciones, que convierta de grados celcuis a kelvin

# %%
def convertirKel(celcuis):
  return float(celcuis) + 273.15

# %%
cel = input("Ingrese los grados celcuis: ")
print("Los grados en kelvin son:", convertirKel(cel))
# Out:
# Ingrese los grados celcuis: 12
# Los grados en kelvin son: 285.15

# %% [markdown]
# Hacer en python el siguiente ejercicio haciendo uso de funciones anonimas, que convierta de grados celcuis a farenheit

# %%
convertir = lambda celcuis: float(celcuis) * 9/5 + 32
cel = input("Ingrese los grados celcuis: ")
print("Los grados en farenheit son:", convertir(cel))
# Out:
# Ingrese los grados celcuis: 12
# Los grados en farenheit son: 53.6

# %% [markdown]
# Hacer en python el siguiente ejercicio haciendo uso de funciones anonimas:
#
# - convertir de farenheit a celcuis
# - convertir de kelvin a celcuis
# - calcular el sueldo de un empleado. hrs * valor de horas * 30 dias
#   las deduciones: ISSS, AFP, ISR
# - elevar un numero a su exponente

# %%
convertirF = lambda farenheit: (float(farenheit) -32) * 9/5
faren = input("Ingrese los grados farenheit: ")
print("Los grados celcuis son: ", convertirF(faren))
# Out:
# Ingrese los grados farenheit: 32
# Los grados celcuis son:  0.0

# %%
convertirK = lambda kelvin: float(kelvin) + 273.15
kel = input("Ingrese los grados kelvin: ")
print("Los grados celcuis son: ", convertirK(kel))
# Out:
# Ingrese los grados kelvin: 0
# Los grados celcuis son:  273.15

# %%
def calculorSueldo(hrs, valor):
  salario_bruto = float(hrs) * float(valor) * 30
  isss = float(salario_bruto * 0.03)  # ISSS es el 3%

  if isss >= 30:
    isss = 30.0

  afp = float(salario_bruto * 0.0725)  # AFP es el 7.25%

  # Renta imponible = salario bruto menos ISSS y AFP
  renta_imponible = salario_bruto - (isss + afp)

  # El ISR se calcula sobre la renta imponible, no sobre el salario bruto
  isr = calcularIsr(renta_imponible)

  sueldo_final = renta_imponible - isr

  print(f"El salario bruto es: {salario_bruto}")
  print(f"El isss es: {isss}")
  print(f"El afp es: {afp}")
  print(f"La renta imponible es: {round(renta_imponible,2)}")
  print(f"El isr retenido es: {round(isr,2)}")
  print(f"El sueldo neto final es: {round(sueldo_final,2)}")


def calcularIsr(monto):
  monto = float(monto)
  # Calculamos el impuesto sobre renta (fórmula oficial: excedente + cuota fija)

  # Tramo 1
  if monto >= 0.01 and monto <= 472.00:
    return 0
  # Tramo 2
  elif monto >= 472.01 and monto <= 895.24:
    return (monto - 472.00) * 0.10 + 17.67
  #Tramo 3
  elif monto >= 895.25 and monto <= 2038.10:
    return (monto - 895.24) * 0.20 + 60.00
  else:
    # Tramo 4
    return (monto - 2038.10) * 0.30 + 288.57

# %%
horas = input("Ingrese el las horas trabajadas: ")
valor = input("Ingrese el pago por hora: ")

calculorSueldo(horas, valor)
# Out:
# Ingrese el las horas trabajadas: 8
# Ingrese el pago por hora: 5
# El salario bruto es: 1200.0
# El isss es: 30.0
# El afp es: 87.0
# La renta imponible es: 1083.0
# El isr retenido es: 97.55
# El sueldo neto final es: 985.45

# %%
def elevar(base,exp):
    res = 1
    for i in range(exp):
      res = res * base
    return res

base = int(input("Ingrese la base: "))
exp = int(input("Ingrese el exponente: "))

print(elevar(base,exp))

# Tambien esta el metodo pow para no complicarnos
print(pow(2,2))
# Out:
# Ingrese la base: 2
# Ingrese el exponente: 2
# 4
# 4
